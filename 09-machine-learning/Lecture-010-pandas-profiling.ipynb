# %% [markdown]
# ## **Pandas Profiling**
# It is a powerful Python library designed to automate the initial stages of **Exploratory Data Analysis (EDA)**.
# It generate a comprehensive, interactive report from a simple Pandas DataFrame, which reduces the time spent on manual data exploration

# %%
import pandas as pd

# %%
df = pd.read_csv('docs/Lecture-010-train.csv')

# %%
df.head()

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Anaconda3\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [27 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\ART\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
# ...

# %% [markdown]
# ### Key Sections of the Report
# * **Overview**
# * **Variables**
# * **Interactions**
# * **Correlations**
# * **Missing Values**
# * **Samples**

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
