# %% [markdown]
# ## **Regression Trees**
#
# ### **Topic Roadmap**
#
# **1. Load a regression dataset**
#
# **2. Train a regression tree**
#
# **3. Evaluate with MAE, RMSE, and R²**
#
# **4. Inspect predictions and tree structure**
#
# **5. Key revision notes**

# %% [markdown]
# ## **1. Dataset and Split**

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

RANDOM_STATE = 42
sns.set_theme(style="whitegrid")
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes(as_frame=True)
X = diabetes.data
y = diabetes.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %% [markdown]
# ## **2. Train the Regression Tree**
#
# A regression tree predicts the mean target value of the training samples in each leaf. `max_depth` is kept small to make the model interpretable.

# %%
from sklearn.tree import DecisionTreeRegressor

reg_tree = DecisionTreeRegressor(max_depth=5, criterion="squared_error", random_state=RANDOM_STATE)
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
predictions = reg_tree.predict(X_test)
metrics = {
    "MAE": mean_absolute_error(y_test, predictions),
    "RMSE": mean_squared_error(y_test, predictions) ** 0.5,
    "R2": r2_score(y_test, predictions),
}
pd.Series(metrics)
# Out:
# MAE     45.936955
# RMSE    59.380262
# R2       0.334482
# dtype: float64

# %% [markdown]
# ## **3. Inspect Predictions and Tree Structure**
#
# The predicted-versus-actual plot reveals systematic under- or over-prediction. The tree plot exposes the learned threshold rules.

# %%
plt.figure(figsize=(7, 6))
sns.scatterplot(x=y_test, y=predictions)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], "r--")
plt.xlabel("Actual target")
plt.ylabel("Predicted target")
plt.title("Regression-tree predictions")
plt.show()

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 10))
plot_tree(reg_tree, feature_names=X.columns, filled=True, rounded=True, max_depth=3)
plt.show()

# %% [markdown]
# ### **Key Revision Notes**
#
# - Regression leaves predict the mean target of the samples that reach them.
# - `squared_error` is the current name for the mean-squared-error split criterion.
# - Tree regressors do not require feature scaling.
# - Deep trees can overfit; use depth, leaf-size, or cost-complexity controls.
